# %%
from metric.detection import MeanAveragePrecision
from stereo_evaluation import StereoEvaluation
from nn.models.faster_rcnn import LitFasterRCNN
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
metric = MeanAveragePrecision(class_metrics=True)
model = LitFasterRCNN.load_from_checkpoint("/home/dennis/git_repos/mslp-dataset/benchmark/nn/faster_rcnn_log/version_0/fasterrcnn-epoch=38-val_loss=0.00.ckpt", map_location="cuda")
model.eval()
eval = StereoEvaluation("/media/dennis/3B9FC6C559F7A944/converted_object_detection_dataset/test", model, metric, 0.8)
metric = eval.estimate()
from pprint import pprint
pprint(metric.compute())
# Out:
# /media/dennis/3B9FC6C559F7A944/anaconda3/envs/benchmark/lib/python3.9/site-packages/pytorch_lightning/utilities/migration/utils.py:52: PossibleUserWarning: The loaded checkpoint was produced with Lightning v2.0.7, which is newer than your current Lightning version: v2.0.6
#   rank_zero_warn(
#   0%|          | 1/310 [00:05<26:42,  5.19s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 0.9999999999999997.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#   3%|▎         | 10/310 [00:35<16:35,  3.32s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 0.9999999999999994.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#   9%|▉         | 28/310 [01:32<13:17,  2.83s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 1.0000000000000000.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#   9%|▉         | 29/310 [01:35<13:24,  2.86s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 0.9999999999999991.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  10%|▉         | 30/310 [01:38<13:36,  2.92s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 1.0000000000000000.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  10%|█         | 31/310 [01:40<12:51,  2.76s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 1.0000000000000000.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  11%|█         | 33/310 [01:46<13:16,  2.88s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 0.9999999999999991.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  11%|█         | 34/310 [01:49<12:41,  2.76s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 1.0000000000000000.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  11%|█▏        | 35/310 [01:52<13:16,  2.90s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 1.0000000000000000.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  12%|█▏        | 36/310 [01:54<12:36,  2.76s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 0.9999999999999999.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  12%|█▏        | 37/310 [01:57<12:22,  2.72s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 1.0000000000000000.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  13%|█▎        | 39/310 [02:03<12:29,  2.77s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 1.0000000000000000.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  13%|█▎        | 40/310 [02:06<12:47,  2.84s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 0.9999999999999999.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  14%|█▎        | 42/310 [02:11<12:46,  2.86s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 0.9999999999999998.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  14%|█▍        | 43/310 [02:14<12:17,  2.76s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 0.9999999999999997.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  15%|█▌        | 47/310 [02:25<11:45,  2.68s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 1.0000000000000000.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  17%|█▋        | 53/310 [02:41<11:30,  2.69s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 0.9999999999999998.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  18%|█▊        | 55/310 [02:46<11:12,  2.64s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 1.0000000000000000.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  19%|█▉        | 60/310 [02:59<10:52,  2.61s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 1.0000000000000000.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  20%|██        | 62/310 [03:05<10:46,  2.61s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 1.0000000000000000.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  20%|██        | 63/310 [03:07<10:54,  2.65s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 1.0000000000000000.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  21%|██        | 64/310 [03:10<10:44,  2.62s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 1.0000000000000000.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  21%|██        | 65/310 [03:12<10:40,  2.61s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 1.0000000000000000.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  22%|██▏       | 67/310 [03:18<10:32,  2.60s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 1.0000000000000000.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  23%|██▎       | 71/310 [03:28<09:56,  2.50s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 0.9999999999999998.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  24%|██▍       | 74/310 [03:35<09:49,  2.50s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 0.9999999999999998.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  26%|██▋       | 82/310 [03:55<09:22,  2.47s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 0.9999999999999996.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  27%|██▋       | 83/310 [03:57<09:19,  2.47s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 1.0000000000000000.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  27%|██▋       | 84/310 [04:00<09:19,  2.47s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 1.0000000000000000.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  28%|██▊       | 86/310 [04:05<09:13,  2.47s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 1.0000000000000000.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  28%|██▊       | 88/310 [04:10<09:07,  2.47s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 0.9999999999999999.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  30%|███       | 93/310 [04:22<08:54,  2.46s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 1.0000000000000000.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#
/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 1.0000000000000000.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  84%|████████▍ | 261/310 [11:39<01:50,  2.26s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 1.0000000000000000.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  85%|████████▌ | 264/310 [11:46<01:47,  2.34s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 1.0000000000000000.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  86%|████████▌ | 266/310 [11:51<01:42,  2.32s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 0.9999999999999997.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  86%|████████▌ | 267/310 [11:53<01:39,  2.31s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 0.9999999999999998.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  86%|████████▋ | 268/310 [11:56<01:37,  2.31s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 1.0000000000000000.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  87%|████████▋ | 271/310 [12:02<01:28,  2.26s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 0.9999999999999991.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  88%|████████▊ | 274/310 [12:09<01:21,  2.26s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 0.9999999999999996.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  89%|████████▊ | 275/310 [12:12<01:21,  2.33s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 0.9999999999999997.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  89%|████████▉ | 276/310 [12:14<01:20,  2.36s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 0.9999999999999996.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  89%|████████▉ | 277/310 [12:16<01:17,  2.34s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 0.9999999999999993.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  90%|█████████ | 280/310 [12:23<01:10,  2.35s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 0.9999999999999992.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  91%|█████████ | 281/310 [12:26<01:06,  2.31s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 0.9999999999999996.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  91%|█████████ | 282/310 [12:28<01:03,  2.26s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 0.9999999999999997.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  91%|█████████▏| 283/310 [12:30<00:59,  2.20s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 1.0000000000000000.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  92%|█████████▏| 284/310 [12:32<00:55,  2.15s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 0.9999999999999998.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  92%|█████████▏| 285/310 [12:34<00:53,  2.13s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 0.9999999999999998.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  92%|█████████▏| 286/310 [12:36<00:50,  2.10s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 0.9999999999999998.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  94%|█████████▍| 291/310 [12:46<00:38,  2.05s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 0.9999999999999997.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  94%|█████████▍| 292/310 [12:48<00:37,  2.09s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 1.0000000000000000.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  95%|█████████▍| 293/310 [12:50<00:35,  2.10s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 0.9999999999999998.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  95%|█████████▍| 294/310 [12:53<00:33,  2.12s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 0.9999999999999998.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  95%|█████████▌| 295/310 [12:55<00:31,  2.10s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 0.9999999999999996.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  95%|█████████▌| 296/310 [12:57<00:29,  2.10s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 0.9999999999999996.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  96%|█████████▌| 297/310 [12:59<00:27,  2.10s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 0.9999999999999999.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  96%|█████████▌| 298/310 [13:01<00:25,  2.10s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 1.0000000000000000.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  96%|█████████▋| 299/310 [13:03<00:23,  2.09s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 0.9999999999999998.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
#  97%|█████████▋| 300/310 [13:05<00:20,  2.08s/it]
# Qhull messages at ~Qhull()
# QH7089 qhull precision warning: The initial hull is narrow.  Is the input lower
# dimensional (e.g., a square in 3-d instead of a cube)?  Cosine of the minimum
# angle is 1.0000000000000000.  If so, Qhull may produce a wide facet.
# Options 'Qs' (search all points), 'Qbb' (scale last coordinate), or
# 'QbB' (scale to unit box) may remove this warning.
# See 'Limitations' in qh-impre.htm.  Use 'Pp' to skip this warning.
# 100%|██████████| 310/310 [13:26<00:00,  2.60s/it]
# {'classes': tensor([1, 2, 3, 4, 5, 6, 8, 9], dtype=torch.int32),
#  'map': tensor(0.),
#  'map_50': tensor(0.),
#  'map_75': tensor(0.),
#  'map_large': tensor(-1.),
#  'map_medium': tensor(-1.),
#  'map_per_class': tensor([0., 0., 0., 0., 0., 0., 0., 0.]),
#  'map_small': tensor(0.),
#  'mar_1': tensor(0.),
#  'mar_10': tensor(0.),
#  'mar_100': tensor(0.),
#  'mar_100_per_class': tensor([0., 0., 0., 0., 0., 0., 0., 0.]),
#  'mar_large': tensor(-1.),
#  'mar_medium': tensor(-1.),
#  'mar_small': tensor(0.)}
